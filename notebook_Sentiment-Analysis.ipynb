# %% [markdown]
# # Creating a Sentiment Analyzer using Yelp Business Reviews

# %% [markdown]
# We're going to go through how to get data off the web using beautifulsoup and the requests module from Python and then later on we'll start analyzing our data cleaning our data.

# %% [markdown]
# ## Scaping the Data from the URL

# %%
import requests
from bs4 import BeautifulSoup

# %%
# creating a request 
r = requests.get("https://www.yelp.com/biz/angelina-paris")

# %%
r.status_code
# Out:
# 200

# %%
# display the html result using .text attribute
r.text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/dcfe403147fc/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>\n            window.yelp = window.yelp || {};\n            window.yelp.cookieTypePreferencesHeader = \'["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]\';\n            window.OneTrust = window.OneTrust || {};\n            window.OneTrust.dataSubjectParams = window.OneTrust.dataSubjectParams || {};\n            window.OneTrust.dataSubjectParams.id = \'\';\n            window.OneTrust.dataSubjectParams.isAnonymous = true;\n\n            function addCookieManagementScript() {\n                var tag = document.createElement(\'script\');\n                tag.async = true;\n                tag.src = \'https://cdn.cookielaw.org/consent/5fbcd417-fbc1-4fcc-abad-f622f1bba72d/otSDKStub.js\';\n                tag.type = \'text/javascript\';\n                tag.charset = \'UTF-8\';\n                tag.setAttribute(\'data-domain-script\', \'5fbcd417-fbc1-4fcc-abad-f622f1bba72d\');\n                tag.setAttribute(\'data-document-language\', \'true\');\n\n                document.head.appendChild(tag);\n            }\n\n            if (\'requestIdleCallback\' in window) {\n                requestIdleCallback(addCookieManagementScript, { timeout: 4000 });\n            } else {\n                setTimeout(addCookieManagementScript, 2000);\n            }\n        </script><script async src="https://www.google-analytics.com/analytics.js"></script><script async src="https://www.googletagmanager.com/gtag/js?id=G-K9Z2ZEVC8C&l=ga4DataLayer"></script><script>window.ga4DataLayer=window.ga4DataLayer||[];function ga4Tag(){ga4DataLayer.push(arguments);};ga4Tag("js",new Date());ga4Tag("config","G-K9Z2ZEVC8C",{send_page_view:false});</script><meta id="emotion-container"><style data-emotion-css="0 xl0fej ymzf9m zar4qi 1b3m20f 39ydts 1d8ba7q 13merx8 12il5ah 7z2yta 1llfbb7 aurft1 z8bp47 1r871ch 1x88bq4 1jr0qsc 1qjitbm ux5mu6 1evauet 1idmmu3 1iuvwzi omlvsn 1enow5j ije6j5 w8rns 1pz4y59 qgunke 1nrzw89 1fnccdf 19sk4h4 f4x8dl 92lxig 1m77lek 9vivtc 1sb02f4 ralh0w 1xvm99p 1u89q5b wonnhn 1mzdwiy 11ydgmk vzslx5 19v1rkv 1s9yq3a 1adhs7a chan6m 6a0jil 1oibaro vently 1t1g2w0 1hqkluu xlzvdl 1avtckp 16owpde 1jqvhu gutk1c rom85o inq9gi 1c2abjj 12i50in 1xv5t8z 1p6t77y 1afdtvl 1nx1n9o 3u4ty oxh9dk 10op6m1 75l6ya fz275b 1lr1m88 1jejxkd 1e53tp2 1wokr28 gx5gvh ddut4h d94q6n zft8kj 16gi3o5 1s2z2pi f9lqif 16m3o60 fev15u w8jrm4 jw6jij foyide 1lx34my ahgoya 1kq79li ncv51b 79elbk 1rjq8gp 16agjqd 174w6ul gnym5v rlqqlq 1gquror 12anxc3 cgap95 4zp531 45sgf 1h0y4i5 s5y3mw rvoh79 160jk0r 1nzu07n 1c994ch 1dvzjst 1hyrt2g na3oda 1yiorgw 1si5cxn 2t3956 rzo1bh 9vrqso xl9jrk 82golp dwca49 lw5ud6 e29med xb3nz6 dh50jt 1jxkguo 182o411 1jac6c2 cwr0q8 ddqa90 fksa8h n65gq3 1vg9j2 147xtl9 11i4m5w f14jpt 1se8maq 1x9ee72 1ir4e44 11z402d 1fdy0l5 13jrydf 1d810fm 1qdduzb 1ytpb90 tza3mu 2sacua vzkfjm 15j7fnr war30n 1inzsq1 r9996t 1jtriov 29kerx 1p9ibgf 1hgawz4 1iog7m3 106vfgv xxqqxs qyp8bo 1wayfxy 4g6ai3 lziufc 1xkgsub w1k3wh ee59jl 1oiyjl1 lsbzdp 9zvmc3 1p80smk xp8w2v 1vhakgw qi10u5 qr9z5e 1lnf5f9">html,body,div,span,applet,object,iframe,h1,h2,h3 ...

# %% [markdown]
# This is not readable so instead we will use BeautifulSoup to refine it.

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
# findall to find all the reviews <p class="comment__09f24__D0cxf css-qgunke"></p>
paragraphs = soup.findAll(class_="comment__09f24__D0cxf css-qgunke")

# %%
type(paragraphs)
# Out:
# bs4.element.ResultSet

# %%
# get each review from the <span> tag inside the <p> tag
reviews = []

for p in paragraphs:
    reviews.append(p.find('span').text) # saving it in an array

# %%
reviews
# Out:
# ['What amazing experiences I did in Paris The food and drink are amazing service %100 perfect All employees have infos about menus \xa0and food ingredient The best drink, ever the hot chocolate you should try it for one \xa0time, because that flavour tastes unforgettable',
#  "Chestnut cake -no good at all. The toppings tasted just like frosting. Way too sweet. I don't understand why is their signature cake. Way Over priced . € 10 a piece",
#  "We waited in line for less than an hour to get seated. The hostess keep the line moving and tables are rotated fairly quickly. Hot chocolate is worth the hype. It's thick and not extremely sweet, which gives you incentive to add more whipped cream to your cup. We also ordered the mount blanc, which was a bit chewy on the outside and generally lacked flavor. I wouldn't recommend it and try something else. Glad we tried the hot chocolate, but with so many other cafes in Paris, not sure if it's worth going back.",
#  "TLDR; angelina offers delicious hot chocolate (it indeed met my expectations). 8.90 gets you cream and a pot that can fill two small teacups to share which satisfied my sweet craving, but the hot chocolate is good enough that i could easily drink my own too. visit on a weekday, particularly in the morning, for a shorter queue.// store, location, service //angelina is located in central paris near rue da rivoli, the gardens, and museums. this location no longer takes reservations, so we arrived at 9:30am on a thursday morning. the queue was short and we waited around 10-15 minutes for a table. our waitress took our order quickly and our hot chocolate arrived very quickly.// chocolat chaud, crème fouetté (hot chocolate, whipped cream) 8.90 //we came to angelina for the hot chocolate. one order gets you a pot which is enough to fill two teacups, along with a small cup of cream. a lot of people order one pot per person, but we decided to start with one (and it ended up being enough for the two of us to share since it is rich and sweet).the hot chocolate was very good! it was clearly made with good quality chocolate, probably dark chocolate. the drink was very rich and it was sweet, but surprisingly not too much. it was also nice to add the bits of cream on the top and let it melt into the drink as we sipped it.we looked at the pastries and other menu items, but they seemed to be quite overpriced and a lot of reviews said they were okay. nothing really caught our eye, so we just got the hot chocolate. i'd recommend angelina for the hot chocolate and would return!",
#  "You can expect to wait in line to get in to Angelina, but the line moves fairly quickly. The hot chocolate is the best I've ever had, and could very well be the best in the entries world. It was so creamy, smooth, served hot, on the sweet side but not too rich. It was absolutely perfect. You definitely need to use all of the whipped cream to cushion the hot chocolate to make it lighter and frothier. I also ordered the croissant roll, scrambled eggs on a bed of bread with comte cheese on top. It was fantastic. Upon my next return to Paris, there's no doubt I'll be running back to Angelina",
#  "It's the best hot chocolate I've had and the best mont blanc. The macarons and croissant were bad. The tart was decent.Would I come again? No.Do you have to come here? In my opinion no. It was a 30 minute wait outside of peak hours and everything was so rich and sweet that we couldn't finish anything. Just go to the right and take out a hot chocolate to try it. If yoy want the mont blanc, go straight to the gift store and buy it there.",
#  "Expect to wait in line for at least 45 minutes (if not more!) when arriving anytime after opening. This is a hugely popular spot in Paris that everyone flocks to. Thankfully, the line to wait in outside is under a covered awning, shielding you from the sun and rain!We chose to stay in line because my fiancé loves hot chocolate and wanted to experience the taste of it here as we'd heard great things. The hot chocolate was absolutely divine! Very rich, smooth and creamy. Definitely the creamiest hot chocolate I've ever tasted! We ordered enough for two, although we should've ordered one to share as it was too rich to drink more than one cup each. Tip for those uninterested in wasting time in line: They have a cart outside the cafe where you can purchase a cup of hot chocolate to go! Please note that the cart isn't always there (we walked by at a later time and noticed it wasn't open) but it's a great way to get to experience the taste of this decadent hot chocolate without the wait.",
#  "We went on a Sunday afternoon and were lucky that we only had to lineup for about 15mins for a table.We got the brunch experience which came with hot chocolate, pastries, a choice of a brunch dish, and choice of dessert dish.The hot chocolate was incredible and the richness was unlike anything we have tasted! However, the butter croissants were very average at best and the brunch dishes (we got the french toast and eggs benedict) were subpar.We also paid extra 10 Euro for the famous Mont Blanc which not only did the presentation look very sloppy, but we found out it's only 8 Euro if you buy from the counter!Overall, not worth the wait if you're looking to get a full sit down brunch. Much better deal skipping the line and buy directly from the counter and gift shop",
#  "Angelina is famous for hot chocolate, so make sure to try that during your visit. It's so rich it causes you to slow down and savor it. Honestly, it's probably the best hot chocolate I've ever had. Adding the whipped cream brings a whole new level to the drink. If you visit after 3 pm, you can enjoy tea time which includes small sandwiches and sweets plus a cup of hot chocolate for 25 euros. There are plenty of other options if you come by at a different time or are not interested in high tea. While Angelina is quite large and the servers do a good job of turning over the tables quickly, be prepared to wait. However, the line outside moves quickly, so don't let it stop you from visiting. If anything, you'll get some time to look through the menu and the gift shop. If you're just visiting the gift shop, you don't need to wait in line.",
#  'Worth the wait! We of course had the hot chocolate - never had anything like it. Also had eggs Benedict which were so nicely displayed on a round toast. Amazing service too!']

# %%
reviews[0]
# Out:
# 'What amazing experiences I did in Paris The food and drink are amazing service %100 perfect All employees have infos about menus \xa0and food ingredient The best drink, ever the hot chocolate you should try it for one \xa0time, because that flavour tastes unforgettable'

# %% [markdown]
# ## Analyzing The Data

# %%
import pandas as pd
import numpy as np

# %%
# converting the list of reviews into a dataframe
df = pd.DataFrame(np.array(reviews), columns=['review'])

# %%
df.head()
# Out:
#                                               review
# 0  What amazing experiences I did in Paris The fo...
# 1  Chestnut cake -no good at all. The toppings ta...
# 2  We waited in line for less than an hour to get...
# 3  TLDR; angelina offers delicious hot chocolate ...
# 4  You can expect to wait in line to get in to An...

# %%
len(df['review'])
# df.shape
# Out:
# 10

# %% [markdown]
# we have 10 reviews

# %% [markdown]
# ## Word count - length of each review

# %%
df['word_count'] = df['review'].apply(lambda x: len(x.split()))

# %%
df.head()
# Out:
#                                               review  word_count
# 0  What amazing experiences I did in Paris The fo...          44
# 1  Chestnut cake -no good at all. The toppings ta...          31
# 2  We waited in line for less than an hour to get...          95
# 3  TLDR; angelina offers delicious hot chocolate ...         288
# 4  You can expect to wait in line to get in to An...         114

# %% [markdown]
# number of characters in each review

# %%
df['character_count'] = df['review'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                               review  word_count  \
# 0  What amazing experiences I did in Paris The fo...          44
# 1  Chestnut cake -no good at all. The toppings ta...          31
# 2  We waited in line for less than an hour to get...          95
# 3  TLDR; angelina offers delicious hot chocolate ...         288
# 4  You can expect to wait in line to get in to An...         114
#
#    character_count
# 0              263
# 1              164
# 2              514
# 3             1584
# 4              594

# %% [markdown]
# ## Average word length

# %%
def average_words(x):
    words = x.split()
    return sum(len(word) for word in words)/len(words)

# %%
df['avg_word_length'] = df['review'].apply(lambda x: average_words(x))

# %%
df.head()
# Out:
#                                               review  word_count  \
# 0  What amazing experiences I did in Paris The fo...          44
# 1  Chestnut cake -no good at all. The toppings ta...          31
# 2  We waited in line for less than an hour to get...          95
# 3  TLDR; angelina offers delicious hot chocolate ...         288
# 4  You can expect to wait in line to get in to An...         114
#
#    character_count  avg_word_length
# 0              263         4.954545
# 1              164         4.322581
# 2              514         4.421053
# 3             1584         4.503472
# 4              594         4.219298

# %% [markdown]
# ## Stopwords in each review

# %%
# importing stopwords list from nltk
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pnwaekwu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
# creating stopwods list
stop_words = stopwords.words('english')

# %%
len(stop_words)
# Out:
# 179

# %%
df['stopwords_count'] = df['review'].apply(lambda x: len([word for word in x.split() if word.lower() in stop_words]))

# %%
df.head(3)
# Out:
#                                               review  word_count  \
# 0  What amazing experiences I did in Paris The fo...          44
# 1  Chestnut cake -no good at all. The toppings ta...          31
# 2  We waited in line for less than an hour to get...          95
#
#    character_count  avg_word_length  stopwords_count
# 0              263         4.954545               19
# 1              164         4.322581               11
# 2              514         4.421053               43

# %% [markdown]
# ## percentage of stopwords to non_stopwords : stopwords ratio or proportion

# %%
df['stopwords_rate'] = df['stopwords_count']/df['word_count']

# %%
df.head(2)
# Out:
#                                               review  word_count  \
# 0  What amazing experiences I did in Paris The fo...          44
# 1  Chestnut cake -no good at all. The toppings ta...          31
#
#    character_count  avg_word_length  stopwords_count  stopwords_rate
# 0              263         4.954545               19        0.431818
# 1              164         4.322581               11        0.354839

# %%
df.sort_values(by = 'stopwords_rate')
# Out:
#                                               review  word_count  \
# 1  Chestnut cake -no good at all. The toppings ta...          31
# 9  Worth the wait! We of course had the hot choco...          32
# 3  TLDR; angelina offers delicious hot chocolate ...         288
# 0  What amazing experiences I did in Paris The fo...          44
# 2  We waited in line for less than an hour to get...          95
# 6  Expect to wait in line for at least 45 minutes...         183
# 4  You can expect to wait in line to get in to An...         114
# 5  It's the best hot chocolate I've had and the b...          87
# 7  We went on a Sunday afternoon and were lucky t...         140
# 8  Angelina is famous for hot chocolate, so make ...         161
#
#    character_count  avg_word_length  stopwords_count  stopwords_rate
# 1              164         4.322581               11        0.354839
# 9              173         4.437500               12        0.375000
# 3             1584         4.503472              119        0.413194
# 0              263         4.954545               19        0.431818
# 2              514         4.421053               43        0.452632
# 6              995         4.442623               83        0.453552
# 4              594         4.219298               52        0.456140
# 5              439         4.057471               40        0.459770
# 7              774         4.535714               66        0.471429
# 8              845         4.254658               76        0.472050

# %%
df.describe()
# Out:
#        word_count  character_count  avg_word_length  stopwords_count  \
# count   10.000000        10.000000        10.000000        10.000000
# mean   117.500000       634.500000         4.414892        52.100000
# std     79.862729       437.420024         0.239256        34.668109
# min     31.000000       164.000000         4.057471        11.000000
# 25%     54.750000       307.000000         4.271639        24.250000
# 50%    104.500000       554.000000         4.429276        47.500000
# 75%    155.750000       827.250000         4.488260        73.500000
# max    288.000000      1584.000000         4.954545       119.000000
#
#        stopwords_rate
# count       10.000000
# mean         0.434042
# std          0.040712
# min          0.354839
# 25%          0.417850
# 50%          0.453092
# 75%          0.458863
# max          0.472050

# %% [markdown]
# ## Data Cleaning and Preprocessing Stage

# %% [markdown]
# seperating each word and transforming thm to lowercase

# %%
df['review_lowercase'] = df['review'].apply(lambda x: " ".join(word.lower() for word in x.split()))

# %%
df.head()
# Out:
#                                               review  word_count  \
# 0  What amazing experiences I did in Paris The fo...          44
# 1  Chestnut cake -no good at all. The toppings ta...          31
# 2  We waited in line for less than an hour to get...          95
# 3  TLDR; angelina offers delicious hot chocolate ...         288
# 4  You can expect to wait in line to get in to An...         114
#
#    character_count  avg_word_length  stopwords_count  stopwords_rate  \
# 0              263         4.954545               19        0.431818
# 1              164         4.322581               11        0.354839
# 2              514         4.421053               43        0.452632
# 3             1584         4.503472              119        0.413194
# 4              594         4.219298               52        0.456140
#
#                                     review_lowercase
# 0  what amazing experiences i did in paris the fo...
# 1  chestnut cake -no good at all. the toppings ta...
# 2  we waited in line for less than an hour to get...
# 3  tldr; angelina offers delicious hot chocolate ...
# 4  you can expect to wait in line to get in to an...

# %% [markdown]
# # Removing Punctuations

# %%
import string

def remove_punctuation(text):
    # Create a translation table to remove punctuation marks
    translator = str.maketrans('', '', string.punctuation)
    # Remove punctuation marks using the translation table
    text = text.translate(translator)
    return text

# %%
df['punctuations'] = df['review_lowercase'].apply(remove_punctuation)

# %%
df['punctuations'].head(10)
# Out:
# 0    what amazing experiences i did in paris the fo...
# 1    chestnut cake no good at all the toppings tast...
# 2    we waited in line for less than an hour to get...
# 3    tldr angelina offers delicious hot chocolate i...
# 4    you can expect to wait in line to get in to an...
# 5    its the best hot chocolate ive had and the bes...
# 6    expect to wait in line for at least 45 minutes...
# 7    we went on a sunday afternoon and were lucky t...
# 8    angelina is famous for hot chocolate so make s...
# 9    worth the wait we of course had the hot chocol...
# Name: punctuations, dtype: object

# %% [markdown]
# ## Removing Stopwords

# %%
stop_words[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
df['stopwords_removed'] = df['punctuations'].apply(lambda x: " ".join(word for word in x.split() if word not in stop_words))

# %%
df['stopwords_removed'].head()
# Out:
# 0    amazing experiences paris food drink amazing s...
# 1    chestnut cake good toppings tasted like frosti...
# 2    waited line less hour get seated hostess keep ...
# 3    tldr angelina offers delicious hot chocolate i...
# 4    expect wait line get angelina line moves fairl...
# Name: stopwords_removed, dtype: object

# %% [markdown]
# ## Review Recurring Words from Frequency count

# %%
pd.Series(" ".join(df['stopwords_removed']).split()).value_counts()[:30]
# Out:
# chocolate    28
# hot          27
# line         11
# wait          9
# angelina      8
# best          7
# rich          7
# drink         7
# cream         7
# quickly       6
# sweet         6
# time          6
# one           6
# good          5
# outside       5
# also          5
# cup           5
# get           5
# paris         5
# enough        4
# blanc         4
# ordered       4
# two           4
# whipped       4
# ive           4
# worth         4
# anything      4
# brunch        4
# gift          4
# try           4
# Name: count, dtype: int64

# %%
other_stopwords = [
    "line", "wait", "best", "rich", "drink", "cream", "quickly", "one", "good",
    "outside", "also", "cup", "get", "enough", "ordered", "two", "ive", "worth",
    "anything", "brunch", "try"
]

# %%
len(other_stopwords)
# Out:
# 21

# %% [markdown]
# ## removing additional stopwords

# %%
df['cleaned_reviews'] = df['stopwords_removed'].apply(lambda x: " ".join(word for word in x.split() if word not in other_stopwords))

# %%
pd.Series(" ".join(df['cleaned_reviews']).split()).value_counts()[:30]
# Out:
# chocolate     28
# hot           27
# angelina       8
# time           6
# sweet          6
# paris          5
# whipped        4
# gift           4
# ever           4
# blanc          4
# got            3
# way            3
# small          3
# pot            3
# visit          3
# eggs           3
# mont           3
# come           3
# go             3
# order          3
# buy            3
# dont           3
# share          3
# amazing        3
# experience     3
# tasted         3
# service        3
# shop           3
# store          2
# probably       2
# Name: count, dtype: int64

# %% [markdown]
# You can go on to remove additional stopwords if you want to.

# %%
df.head()
# Out:
#                                               review  word_count  \
# 0  What amazing experiences I did in Paris The fo...          44
# 1  Chestnut cake -no good at all. The toppings ta...          31
# 2  We waited in line for less than an hour to get...          95
# 3  TLDR; angelina offers delicious hot chocolate ...         288
# 4  You can expect to wait in line to get in to An...         114
#
#    character_count  avg_word_length  stopwords_count  stopwords_rate  \
# 0              263         4.954545               19        0.431818
# 1              164         4.322581               11        0.354839
# 2              514         4.421053               43        0.452632
# 3             1584         4.503472              119        0.413194
# 4              594         4.219298               52        0.456140
#
#                                     review_lowercase  \
# 0  what amazing experiences i did in paris the fo...
# 1  chestnut cake -no good at all. the toppings ta...
# 2  we waited in line for less than an hour to get...
# 3  tldr; angelina offers delicious hot chocolate ...
# 4  you can expect to wait in line to get in to an...
#
#                                         punctuations  \
# 0  what amazing experiences i did in paris the fo...
# 1  chestnut cake no good at all the toppings tast...
# 2  we waited in line for less than an hour to get...
# 3  tldr angelina offers delicious hot chocolate i...
# 4  you can expect to wait in line to get in to an...
#
#                                    stopwords_removed  \
# 0  amazing experiences paris food drink amazing s...
# 1  chestnut cake good toppings tasted like frosti...
# 2  waited line less hour get seated hostess keep ...
# 3  tldr angelina offers delicious hot chocolate i...
# 4  expect wait line get angelina line moves fairl...
#
#                                      cleaned_reviews
# 0  amazing experiences paris food amazing service...
# 1  chestnut cake toppings tasted like frosting wa...
# 2  waited less hour seated hostess keep moving ta...
# 3  tldr angelina offers delicious hot chocolate i...
# 4  expect angelina moves fairly hot chocolate eve...

# %% [markdown]
# ## Lemmatization

# %%
from textblob import Word
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\pnwaekwu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\pnwaekwu\AppData\Roaming\nltk_data...
# True

# %%
df['lemmatized'] = df['cleaned_reviews'].apply(lambda x: " ".join(Word(word).lemmatize() for word in x.split()))

# %%
df['lemmatized']
# Out:
# 0    amazing experience paris food amazing service ...
# 1    chestnut cake topping tasted like frosting way...
# 2    waited le hour seated hostess keep moving tabl...
# 3    tldr angelina offer delicious hot chocolate in...
# 4    expect angelina move fairly hot chocolate ever...
# 5    hot chocolate mont blanc macarons croissant ba...
# 6    expect least 45 minute arriving anytime openin...
# 7    went sunday afternoon lucky lineup 15mins tabl...
# 8    angelina famous hot chocolate make sure visit ...
# 9    course hot chocolate never like egg benedict n...
# Name: lemmatized, dtype: object

# %%
df['cleaned_reviews']
# Out:
# 0    amazing experiences paris food amazing service...
# 1    chestnut cake toppings tasted like frosting wa...
# 2    waited less hour seated hostess keep moving ta...
# 3    tldr angelina offers delicious hot chocolate i...
# 4    expect angelina moves fairly hot chocolate eve...
# 5    hot chocolate mont blanc macarons croissant ba...
# 6    expect least 45 minutes arriving anytime openi...
# 7    went sunday afternoon lucky lineup 15mins tabl...
# 8    angelina famous hot chocolate make sure visit ...
# 9    course hot chocolate never like eggs benedict ...
# Name: cleaned_reviews, dtype: object

# %% [markdown]
# ##  Sentiment Analysis

# %%
from textblob import TextBlob

# %% [markdown]
# when you run sentiment analysis you actually get two metrics back so you get a polarity metric and you get a subjectivity metric.
#
# Now the polarity metric is probably the one that we're more interested in because it gives us a value from -1 to 1. which is a metric of how positive positive or how negative a review is, so -1 being negative and 1 obviously being positive vice-versa.
#
# subjectivity is a metric between 0 and 1 and it's a measure of how much the text is based on factual information versus just generic opinion, so ideally if you wanted a really constructive review you're probably looking for something which is.. I mean you could say it's objective but you probably want a little bit of personal opinion in that as well.
#
# but you ideally want something that's not too negative, not too positive. but if you're looking for example your biggest critics you'll be looking for something which is super subjective and also I guess reasonably negative because you're sort of getting right down to the bottom of barrel in terms of I guess the worst bits about your business.

# %%
df['polarity'] = df['lemmatized'].apply(lambda x: TextBlob(x).sentiment[0])

# %%
df['subjectivity'] = df['lemmatized'].apply(lambda x: TextBlob(x).sentiment[1])

# %%
df.drop(['review_lowercase', 'punctuations',
       'stopwords_removed', 'cleaned_reviews', 'lemmatized'], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                                               review  word_count  \
# 0  What amazing experiences I did in Paris The fo...          44
# 1  Chestnut cake -no good at all. The toppings ta...          31
#
#    character_count  avg_word_length  stopwords_count  stopwords_rate  \
# 0              263         4.954545               19        0.431818
# 1              164         4.322581               11        0.354839
#
#    polarity  subjectivity
# 0      0.65          0.93
# 1      0.35          0.65

# %%
df.sort_values(by='polarity')
# Out:
#                                               review  word_count  \
# 5  It's the best hot chocolate I've had and the b...          87
# 7  We went on a Sunday afternoon and were lucky t...         140
# 8  Angelina is famous for hot chocolate, so make ...         161
# 2  We waited in line for less than an hour to get...          95
# 4  You can expect to wait in line to get in to An...         114
# 3  TLDR; angelina offers delicious hot chocolate ...         288
# 6  Expect to wait in line for at least 45 minutes...         183
# 9  Worth the wait! We of course had the hot choco...          32
# 1  Chestnut cake -no good at all. The toppings ta...          31
# 0  What amazing experiences I did in Paris The fo...          44
#
#    character_count  avg_word_length  stopwords_count  stopwords_rate  \
# 5              439         4.057471               40        0.459770
# 7              774         4.535714               66        0.471429
# 8              845         4.254658               76        0.472050
# 2              514         4.421053               43        0.452632
# 4              594         4.219298               52        0.456140
# 3             1584         4.503472              119        0.413194
# 6              995         4.442623               83        0.453552
# 9              173         4.437500               12        0.375000
# 1              164         4.322581               11        0.354839
# 0              263         4.954545               19        0.431818
#
#    polarity  subjectivity
# 5  0.105952      0.658730
# 7  0.218056      0.594444
# 8  0.219416      0.638250
# 2  0.233333      0.634877
# 4  0.241667      0.633333
# 3  0.246000      0.640000
# 6  0.283333      0.670000
# 9  0.312500      0.787500
# 1  0.350000      0.650000
# 0  0.650000      0.930000

# %%
print(list(df['review'][0:][:1]))
# Out:
# ['What amazing experiences I did in Paris The food and drink are amazing service %100 perfect All employees have infos about menus \xa0and food ingredient The best drink, ever the hot chocolate you should try it for one \xa0time, because that flavour tastes unforgettable']

# %% [markdown]
# # Conclusion

# %% [markdown]
# From the data we see that the polarity values range from 0.105952 to 0.787500. The higher the polarity value, the more positive the sentiment expressed in the corresponding review.
#
# the subjectivity values range from 0.594444 to 0.930000. Higher subjectivity values indicate that the corresponding reviews are more opinionated and subjective.
#
# It's important to note that the polarity and subjectivity values are calculated based on the specific sentiment analysis algorithm or tool used, and the interpretation may vary depending on the scale and context of the analysis.
#
# in Conclusion, The polarity values range from 0.105952 to 0.787500, with higher values indicating a more positive sentiment. This suggests that customers generally had positive experiences at the restaurant. The highest polarity value of 0.787500 indicates a strong positive sentiment in one of the reviews.
#
# Regarding subjectivity, the values range from 0.594444 to 0.930000. These values indicate that the reviews are relatively subjective, implying that customers expressed personal opinions and emotions rather than purely objective statements.
#
# Overall, it seems that the restaurant received favorable feedback from customers based on the sentiment analysis results. However, it's important to consider that these conclusions are based solely on the polarity and subjectivity metrics obtained from the sentiment analysis. Additional context and the specific criteria used to determine the sentiment may provide a more comprehensive understanding of the restaurant's overall reputation.
